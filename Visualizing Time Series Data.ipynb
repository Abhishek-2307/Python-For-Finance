# %% [markdown]
# ### Importing Modules for Analysis

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
stock = pd.read_csv('stock_data.csv')

# %%
stock.head(2)
# Out:
#    Day  Price
# 0    1  78.72
# 1    2  78.31

# %%
stock2 = pd.read_csv('stock_data2.csv')

# %%
stock2.head(2)
# Out:
#    day  company1   company2
# 0    1     78.72  62.957142
# 1    2     78.31  62.185715

# %%
days1 = stock[['Day']]
prices = stock[['Price']]

# %%
# Plot x_data and y_data as specified
plt.plot(days1, prices, color="red", linestyle="--")

# Display the plot
plt.show()

# %% [markdown]
# ### Adding Axix labels and Tiles

# %%
# Plot price as a function of time
plt.plot(days, prices, color="red", linestyle="--")

# Add x and y labels
plt.xlabel('Days')
plt.ylabel('Prices, $')

# Add plot title
plt.title('Company Stock Prices Over Time')

# Show plot
plt.show()

# %% [markdown]
# ### Multiple lines on same plot

# %%
prices1 = stock2[['company1']]
prices2 = stock2[['company2']]
days = stock2[['day']]

# %%
# Plot two lines of varying colors 
plt.plot(days, prices1, color='red')
plt.plot(days, prices2, color='green')

# Add labels
plt.xlabel('Days')
plt.ylabel('Prices, $')
plt.title('Stock Prices Over Time')
plt.show()

# %% [markdown]
# #### Scatterplot

# %%
# Plot price as a function of time
plt.scatter(days1, prices, color='green', s=0.1)

# Show plot
plt.show()

# %% [markdown]
# #### Is data normally distributed?

# %%
# Plot histogram with 100 bins
plt.hist(stock['Price'],bins=100)
# Display plot
plt.show()

# %% [markdown]
# #### Comparing two histograms

# %%
# Plot histogram of stocks_A
plt.hist(stock2['company1'], bins=100, alpha=0.4)

# Plot histogram of stocks_B
plt.hist(stock2['company2'], bins=100, alpha=0.4)

# Display plot
plt.show()

# %% [markdown]
# #### Adding a legend

# %%
# Plot stock_A and stock_B histograms
plt.hist(stock_A, bins=100, alpha=0.4, label='Stock A')
plt.hist(stock_B, bins=100, alpha=0.4, label='Stock B')

# Add the legend
plt.legend()

# Display the plot
plt.show()
